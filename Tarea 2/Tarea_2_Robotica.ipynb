# %% [markdown]
# ## P1

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from google.colab import drive
import math

# %%
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p1/imagen01.jpg"
# Out:
# --2024-05-13 02:54:30--  https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea%202/p1/imagen01.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 427264 (417K) [image/jpeg]
# Saving to: ‘imagen01.jpg’
#
# imagen01.jpg        100%[===================>] 417.25K  --.-KB/s    in 0.04s
#
# 2024-05-13 02:54:30 (10.7 MB/s) - ‘imagen01.jpg’ saved [427264/427264]

# %%
import requests
from PIL import Image
from io import BytesIO

# Abrir la imagen con PIL
image = cv2.imread("imagen01.jpg")

# Convertir la imagen PIL a un arreglo numpy
imagen_cv2 = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)

# %%
# Convertir la imagen a escala de grises
gray_image = cv2.cvtColor(imagen_cv2, cv2.COLOR_BGR2GRAY)

# Aplicar el detector de Canny
lower_threshold = 160
upper_threshold = 480
edges = cv2.Canny(gray_image, lower_threshold, upper_threshold)

# Mostrar la imagen resultante con los bordes detectados
cv2_imshow(gray_image)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1024x680>
# <PIL.Image.Image image mode=L size=1024x680>

# %%
# Leer la imagen
src = gray_image
dst = cv2.Canny(src, 160, 480, None, 3)

# Copy edges to the images that will display the results in BGR
cdst = cv2.cvtColor(dst, cv2.COLOR_GRAY2BGR)
cdstP = np.copy(cdst)

lines = cv2.HoughLines(dst, 1, np.pi / 180, 150, None, 0, 0)

if lines is not None:
 for i in range(0, len(lines)):
  rho = lines[i][0][0]
  theta = lines[i][0][1]
  a = math.cos(theta)
  b = math.sin(theta)
  x0 = a * rho
  y0 = b * rho
  pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
  pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
  cv2.line(cdst, pt1, pt2, (0,0,255), 3, cv2.LINE_AA)


linesP = cv2.HoughLinesP(dst, 1, np.pi / 180, 50, None, 50, 10)

if linesP is not None:
  for i in range(0, len(linesP)):
    l = linesP[i][0]
    cv2.line(cdstP, (l[0], l[1]), (l[2], l[3]), (0,0,255), 3, cv2.LINE_AA)

cv2_imshow(src)
cv2_imshow(cdst)
cv2_imshow(cdstP)
# Out:
# <PIL.Image.Image image mode=L size=1024x680>
# <PIL.Image.Image image mode=RGB size=1024x680>
# <PIL.Image.Image image mode=RGB size=1024x680>

# %% [markdown]
# ## P2

# %%
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_10.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_12.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_12.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_14.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_15.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_18.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_19.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_2.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_20.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_21.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_22.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_23.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_24.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_25.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_26.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_27.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_29.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_30.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_40.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_41.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_42.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_43.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_44.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_46.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_47.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_48.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_49.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_5.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_50.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_57.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_6.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_62.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_64.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_65.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_70.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_71.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_72.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_73.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_75.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_8.jpg"
# !wget "https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea 2/p2/image_9.jpg"
# Out:
# --2024-05-13 02:54:31--  https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea%202/p2/image_10.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57432 (56K) [image/jpeg]
# Saving to: ‘image_10.jpg’
#
# image_10.jpg        100%[===================>]  56.09K  --.-KB/s    in 0.01s
#
# 2024-05-13 02:54:32 (4.81 MB/s) - ‘image_10.jpg’ saved [57432/57432]
#
# --2024-05-13 02:54:32--  https://raw.githubusercontent.com/X4ero26/Robotica/main/Tarea%202/p2/image_12.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
import glob
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# Definir las coordenadas del mundo real de los puntos 3D
objp = np.zeros((6*9, 3), np.float32)
objp[:, :2] = np.mgrid[0:9, 0:6].T.reshape(-1, 2)

# Arrays para almacenar los puntos 3D y 2D de todas las imágenes
objpoints = [] # puntos 3D en el espacio del mundo
imgpoints = [] # puntos 2D en el plano de la imagen

# Cargar las imágenes
images = glob.glob('image_*.jpg')

for fname in images:
    img = cv2.imread(fname)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Encontrar las esquinas del tablero de ajedrez
    ret, corners = cv2.findChessboardCorners(gray, (9, 6), None)

    # Si se encuentran las esquinas, agregar puntos 3D y 2D
    if ret == True:
        objpoints.append(objp)
        corners2 = cv2.cornerSubPix(gray, corners, (11, 11), (-1, -1), criteria)
        imgpoints.append(corners2)

# Calibrar la cámara
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)

# Mostrar los resultados
print("Matriz de la cámara:\n", mtx)
print("Coeficientes de distorsión:\n", dist)
print("Vectores de rotación:\n", rvecs)
print("Vectores de traslación:\n", tvecs)
# Out:
# Matriz de la cámara:
#  [[503.79080737   0.         313.80573857]
#  [  0.         503.49847433 243.30923266]
#  [  0.           0.           1.        ]]
# Coeficientes de distorsión:
#  [[ 2.08365581e-01 -4.69764652e-01  4.68869442e-04 -1.85580049e-03
#    2.40400543e-01]]
# Vectores de rotación:
#  (array([[0.2420272 ],
#        [0.54454108],
#        [3.02683017]]), array([[-1.44764591],
#        [-0.41678462],
#        [ 2.56185534]]), array([[-1.08333243],
#        [-0.30258099],
#        [ 2.80151941]]), array([[-0.01741583],
#        [ 0.45665827],
#        [ 3.10949622]]), array([[0.06814018],
#        [0.06533316],
#        [3.13231322]]), array([[0.86142692],
#        [0.21765203],
#        [2.88427839]]), array([[ 0.11151155],
#        [-0.4797971 ],
#        [-3.08461618]]), array([[0.04590726],
#        [0.04908939],
#        [3.13758249]]), array([[0.16238616],
#        [0.58855646],
#        [3.03791376]]), array([[-1.23758905],
#        [ 0.11541846],
# ...
